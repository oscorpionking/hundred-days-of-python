# %%
#Project Treasure Island
#we got the graphic below from Ascii.co.uk
'''*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/[TomekK]
*******************************************************************************'''
name = input("what is your name?\n")
def greet():
    print(f"Hello {name}, welcome to the Treasure Island! \n I am going to guide you through the game, lets's go!")
    
def gameon():
    print("Congratulations for making it this far. \n I have fed your horse, let's go!")
   
greet()


    
print("You have just reached a cross-road \n do you want to turn left or right?")

decision = input("What will you like to do?")
decision = decision.lower()
print(f"Your decision is: {decision}")
if "left" in decision:
    print("Congratulations!, you're still in the game! \n .................. moving............")
    gameon()
    game = 1
else:
    game = 0
    print("sorry, you just made a wrong decsion. \n....You have just fallen into a hole....\n ......game over!....")
    
    
if game == 1:
    print("You just got to a stream. \n If you wait, your friends may arrive in a boat, and you don't know what time that might be. \n The stream looks a bit shallow.")
    decision = input("What will you like to do?\n wait or swim?")
    decision = decision.lower()
    if "wait" in decision:
        print("Congratulations!, you're still in the game! \n .................. moving............")
        gameon()
        game = 1
    else:
        game = 0
        print("sorry, you just made a wrong decsion. \n....You just got attacked by a crocodile in the stream....\n ......game over!....")  

if game ==1:
    print(" What a long adventure\n You're a lucky one. \n Now you just came to a large castle with three entrance doors \n red \n blue \n yellow ")
    decision = input("Which of the doors will you like to enter?")
    decision = decision.lower()
    if "red" in decision:
        game = 0
        print("sorry, you just made a wrong decsion. \n....You just got entered the furnance....\n ......game over!....")
    elif "blue" in decision:
        game = 0
        print("sorry, you just made a wrong decsion. \n....That's the lions' den! you just got turn apart....\n ......game over!....")
    elif "yellow" in decision:
        print("Congratualtions! that's the door to the throne room! welcome to meet the queen")
    else:
        print("whoops! that's wrong. Please check the options and try again!")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\`'
# <>:3: SyntaxWarning: invalid escape sequence '\`'
# C:\Users\ozoem\AppData\Local\Temp\ipykernel_36060\3069956201.py:3: SyntaxWarning: invalid escape sequence '\`'
#   '''*******************************************************************************
# Hello Ogedegede, welcome to the Treasure Island!
#  I am going to guide you through the game, lets's go!
# You have just reached a cross-road
#  do you want to turn left or right?
# Your decision is: left
# Congratulations!, you're still in the game!
#  .................. moving............
# Congratulations for making it this far.
#  I have fed your horse, let's go!
# You just got to a stream.
#  If you wait, your friends may arrive in a boat, and you don't know what time that might be.
#  The stream looks a bit shallow.
# Congratulations!, you're still in the game!
#  .................. moving............
# Congratulations for making it this far.
#  I have fed your horse, let's go!
# ...
